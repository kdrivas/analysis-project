# %%
import pandas as pd
import numpy as np

# %%
path='input/'

# %%
base_col=['Id_HistoricoJob','Id_Job','Id_Malla','Fecha_Carga_Scheduler','Fecha_Ejec_Inicio','Fecha_Ejec_Fin',
          'Duracion','Promedio','Agente','Mxrc','Maxcmpc','Grupo','Force_Complete','CCF','Estado']

# %%
df=pd.DataFrame()
for i in range(8):
    auxdf= pd.read_excel(path+'HistoricoJob0'+str(i+1)+'.csv.xlsx')
    df=df.append(auxdf,ignore_index=True)
    print(df.shape)
    
df.head(20)
# Out:
# (1000000, 15)
# (2000000, 15)
# (3000000, 15)
# (3989785, 15)
# (4989785, 15)
# (5989785, 15)
# (6989785, 15)
# (7178825, 15)
#     Id_HistoricoJob    Id_Job  Id_Malla Fecha_Carga_Scheduler  \
# 0            559926  @DF2BYIX  02E2BXH9   2017-06-12 14:55:00
# 1            559927  @DF2FCL2  02FBFCL4   2017-06-12 14:55:00
# 2            559928  @DF2FCL4  02FBFCL2   2017-06-12 14:55:00
# 3            559929  @DF2IACV  02FBFCL2   2017-06-12 14:55:00
# 4            559930  @DF2WN92  02WNH992   2017-06-12 14:55:00
# 5            559931  @DF2WN94  02WNH992   2017-06-12 14:55:00
# 6            559932  @DF2WN96  02WNH992   2017-06-12 14:55:00
# 7            559933  @DF2WN98  02WNH992   2017-06-12 14:55:00
# 8            559934  @DF2WN90  02WNH992   2017-06-12 14:55:00
# 9            559935  @DF2WN91  02WNH992   2017-06-12 14:55:00
# 10           559936  @DF2WN93  02WNH992   2017-06-12 14:55:00
# 11           559937  @DF2WN95  02WNH992   2017-06-12 14:55:00
# ...

# %%
df.to_csv(path+'BaseHistoricoJobInicial.csv',encoding='latin1',sep=';')
